# %%
import pandas as pd
import matplotlib.pyplot as plt

merged_df = pd.read_csv("data/Final_Data.csv")
trip_summary_df = pd.read_csv("data/trip_summary.csv")
df_vehicle = pd.read_csv("data/vehicle.csv")
df_tripReq = pd.read_csv("data/trip_request.csv")
route_df = pd.read_csv("data/route.csv")
# Out:
# /var/folders/zw/g36h_k5s02q7_zm370bn25pw0000gn/T/ipykernel_64659/643907223.py:4: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_df = pd.read_csv("data/Final_Data.csv")

# %%
# View the first 5 rows of the data frame
merged_df.head()

# View the shape of the data frame
merged_df.shape

# Get a summary of the data frame
merged_df.describe()

# Check for missing values
merged_df.isnull().sum()

# Check for correlation between variables
corr_matrix = merged_df.corr()
plt.matshow(corr_matrix)
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=90)
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)
plt.colorbar()
plt.show()

# %%
# View the first 5 rows of the data frame
trip_summary_df.head()

# View the shape of the data frame
trip_summary_df.shape

# Get a summary of the data frame
trip_summary_df.describe()

# Check for missing values
trip_summary_df.isnull().sum()

# Check for correlation between variables
corr_matrix = trip_summary_df.corr()
plt.matshow(corr_matrix)
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=90)
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)
plt.colorbar()
plt.show()

# %%
# View the first 5 rows of the data frame
df_vehicle.head()

# View the shape of the data frame
df_vehicle.shape

# Get a summary of the data frame
df_vehicle.describe()

# Check for missing values
df_vehicle.isnull().sum()

# Check for correlation between variables
corr_matrix = df_vehicle.corr()
plt.matshow(corr_matrix)
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=90)
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)
plt.colorbar()
plt.show()

# %%
# View the first 5 rows of the data frame
df_tripReq.head()

# View the shape of the data frame
df_tripReq.shape

# Get a summary of the data frame
df_tripReq.describe()

# Check for missing values
df_tripReq.isnull().sum()

# Check for correlation between variables
corr_matrix = df_tripReq.corr()
plt.matshow(corr_matrix)
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=90)
plt.yticks(range
# Out:
#   File "/var/folders/zw/g36h_k5s02q7_zm370bn25pw0000gn/T/ipykernel_64659/3150135962.py", line 19
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
# View the first 5 rows of the data frame
route_df.head()

# View the shape of the data frame
route_df.shape

# Get a summary of the data frame
route_df.describe()

# Check for missing values
route_df.isnull().sum()

# Check for correlation between variables
corr_matrix = route_df.corr()
plt.matshow(corr_matrix)
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=90)
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)
plt.colorbar()
plt.show()
